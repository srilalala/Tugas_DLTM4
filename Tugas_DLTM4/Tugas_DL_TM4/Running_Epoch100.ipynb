# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'natural-images:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F42780%2F75676%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240501%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240501T082619Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading natural-images, 358905792 bytes compressed
# [==================================================] 358905792 bytes downloaded
# Downloaded and uncompressed: natural-images
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        (os.path.join(dirname, filename))
# Any results you write to the current directory are saved as output.

# %%
labels = os.listdir('../input/natural-images/data/natural_images/')
print(labels)
# Out:
# ['car', 'motorbike', 'person', 'airplane', 'fruit', 'flower', 'cat', 'dog']

# %%
from IPython.display import Image, display
num = []
for label in labels:
    path = '../input/natural-images/data/natural_images/{0}/'.format(label)
    folder_data = os.listdir(path)
    k = 0
    print('\n', label.upper())
    for image_path in folder_data:
        if k < 5:
            display(Image(path+image_path))
        k = k+1
    num.append(k)
    print('there are ', k,' images in ', label, 'class')
# Out:
#  CAR
# there are  968  images in  car class
#
#  MOTORBIKE
# there are  788  images in  motorbike class
#
#  PERSON
# there are  986  images in  person class
#
#  AIRPLANE
# there are  727  images in  airplane class
#
#  FRUIT
# there are  1000  images in  fruit class
#
#  FLOWER
# there are  843  images in  flower class
#
#  CAT
# there are  885  images in  cat class
#
#  DOG
# there are  702  images in  dog class

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (8,8))
plt.bar(labels, num)
plt.title('NUMBER OF IMAGES CONTAINED IN EACH CLASS')
plt.xlabel('classes')
plt.ylabel('count')
plt.show()

# %%
x_data =[]
y_data = []
import cv2
for label in labels:
    path = '../input/natural-images/data/natural_images/{0}/'.format(label)
    folder_data = os.listdir(path)
    for image_path in folder_data:
        image = cv2.imread(path+image_path)
        image_resized = cv2.resize(image, (32,32))
        x_data.append(np.array(image_resized))
        y_data.append(label)

# %%
x_data = np.array(x_data)
y_data = np.array(y_data)
print('the shape of X is: ', x_data.shape, 'and that of Y is: ', y_data.shape)
# Out:
# the shape of X is:  (6899, 32, 32, 3) and that of Y is:  (6899,)

# %%
#stadardizing the input data
x_data = x_data.astype('float32')/255

# %%
#converting the y_data into categorical:
from sklearn.preprocessing import LabelEncoder
y_encoded = LabelEncoder().fit_transform(y_data)
from keras.utils import to_categorical
y_categorical = to_categorical(y_encoded)

# %%
#lets shuffle all the data we have:
r = np.arange(x_data.shape[0])
np.random.seed(42)
np.random.shuffle(r)
X = x_data[r]
Y = y_categorical[r]

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into training, validation, and testing sets
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=0.5, random_state=42)

# %%
#structuring the CNN model
from keras import models, layers
model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=X_train.shape[1:]))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2, 2)))
model.add(layers.Dropout(rate=0.25))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dropout(rate=0.5))
model.add(layers.Dense(8, activation='softmax'))

# %%
#let's compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# %%
#fitting the model
history = model.fit(X_train, Y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 121/121 [==============================] - 9s 65ms/step - loss: 1.1891 - accuracy: 0.5703 - val_loss: 0.6410 - val_accuracy: 0.7660
# Epoch 2/100
# 121/121 [==============================] - 9s 73ms/step - loss: 0.6142 - accuracy: 0.7844 - val_loss: 0.4919 - val_accuracy: 0.8302
# Epoch 3/100
# 121/121 [==============================] - 6s 46ms/step - loss: 0.4639 - accuracy: 0.8291 - val_loss: 0.4786 - val_accuracy: 0.8126
# Epoch 4/100
# 121/121 [==============================] - 6s 48ms/step - loss: 0.3784 - accuracy: 0.8558 - val_loss: 0.3542 - val_accuracy: 0.8602
# Epoch 5/100
# 121/121 [==============================] - 6s 50ms/step - loss: 0.3528 - accuracy: 0.8646 - val_loss: 0.3424 - val_accuracy: 0.8716
# Epoch 6/100
# 121/121 [==============================] - 5s 43ms/step - loss: 0.2809 - accuracy: 0.9011 - val_loss: 0.3181 - val_accuracy: 0.8768
# Epoch 7/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.2504 - accuracy: 0.9037 - val_loss: 0.3560 - val_accuracy: 0.8685
# Epoch 8/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.2297 - accuracy: 0.9159 - val_loss: 0.2643 - val_accuracy: 0.8903
# Epoch 9/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.2062 - accuracy: 0.9208 - val_loss: 0.3172 - val_accuracy: 0.8789
# Epoch 10/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.1802 - accuracy: 0.9337 - val_loss: 0.3168 - val_accuracy: 0.8861
# Epoch 11/100
# 121/121 [==============================] - 6s 52ms/step - loss: 0.1665 - accuracy: 0.9379 - val_loss: 0.2708 - val_accuracy: 0.8954
# Epoch 12/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.1461 - accuracy: 0.9477 - val_loss: 0.3369 - val_accuracy: 0.8820
# Epoch 13/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.1544 - accuracy: 0.9446 - val_loss: 0.2697 - val_accuracy: 0.8986
# Epoch 14/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.1436 - accuracy: 0.9475 - val_loss: 0.2814 - val_accuracy: 0.8882
# Epoch 15/100
# 121/121 [==============================] - 6s 48ms/step - loss: 0.1111 - accuracy: 0.9612 - val_loss: 0.2994 - val_accuracy: 0.8986
# Epoch 16/100
# 121/121 [==============================] - 6s 50ms/step - loss: 0.1074 - accuracy: 0.9625 - val_loss: 0.2628 - val_accuracy: 0.8913
# Epoch 17/100
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0887 - accuracy: 0.9684 - val_loss: 0.2703 - val_accuracy: 0.9048
# Epoch 18/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0740 - accuracy: 0.9762 - val_loss: 0.2571 - val_accuracy: 0.9130
# Epoch 19/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.1144 - accuracy: 0.9599 - val_loss: 0.2489 - val_accuracy: 0.9048
# Epoch 20/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0689 - accuracy: 0.9770 - val_loss: 0.2595 - val_accuracy: 0.9048
# Epoch 21/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0713 - accuracy: 0.9767 - val_loss: 0.3280 - val_accuracy: 0.8986
# Epoch 22/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0643 - accuracy: 0.9764 - val_loss: 0.3242 - val_accuracy: 0.9037
# Epoch 23/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0610 - accuracy: 0.9803 - val_loss: 0.2715 - val_accuracy: 0.9027
# Epoch 24/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0560 - accuracy: 0.9806 - val_loss: 0.3148 - val_accuracy: 0.8934
# Epoch 25/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0621 - accuracy: 0.9788 - val_loss: 0.3685 - val_accuracy: 0.8872
# Epoch 26/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0597 - accuracy: 0.9798 - val_loss: 0.3300 - val_accuracy: 0.9048
# Epoch 27/100
# 121/121 [==============================] - 6s 46ms/step - loss: 0.0582 - accuracy: 0.9793 - val_loss: 0.3221 - val_accuracy: 0.9058
# Epoch 28/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.0460 - accuracy: 0.9840 - val_loss: 0.3302 - val_accuracy: 0.8996
# Epoch 29/100
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0406 - accuracy: 0.9873 - val_loss: 0.3333 - val_accuracy: 0.9006
# Epoch 30/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0649 - accuracy: 0.9806 - val_loss: 0.3131 - val_accuracy: 0.9006
# Epoch 31/100
# 121/121 [==============================] - 6s 52ms/step - loss: 0.0437 - accuracy: 0.9845 - val_loss: 0.3662 - val_accuracy: 0.9006
# Epoch 32/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0496 - accuracy: 0.9847 - val_loss: 0.3023 - val_accuracy: 0.9079
# Epoch 33/100
# 121/121 [==============================] - 8s 67ms/step - loss: 0.0404 - accuracy: 0.9865 - val_loss: 0.4009 - val_accuracy: 0.8934
# Epoch 34/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0606 - accuracy: 0.9783 - val_loss: 0.3623 - val_accuracy: 0.8986
# Epoch 35/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0443 - accuracy: 0.9852 - val_loss: 0.3748 - val_accuracy: 0.9027
# Epoch 36/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0504 - accuracy: 0.9829 - val_loss: 0.3209 - val_accuracy: 0.9079
# Epoch 37/100
# 121/121 [==============================] - 6s 49ms/step - loss: 0.0443 - accuracy: 0.9865 - val_loss: 0.3220 - val_accuracy: 0.9048
# Epoch 38/100
# 121/121 [==============================] - 6s 47ms/step - loss: 0.0463 - accuracy: 0.9855 - val_loss: 0.3870 - val_accuracy: 0.8965
# Epoch 39/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0450 - accuracy: 0.9860 - val_loss: 0.3768 - val_accuracy: 0.8944
# Epoch 40/100
# 121/121 [==============================] - 7s 54ms/step - loss: 0.0300 - accuracy: 0.9925 - val_loss: 0.3930 - val_accuracy: 0.9006
# Epoch 41/100
# 121/121 [==============================] - 5s 44ms/step - loss: 0.0347 - accuracy: 0.9878 - val_loss: 0.5289 - val_accuracy: 0.8841
# Epoch 42/100
# 121/121 [==============================] - 7s 54ms/step - loss: 0.0539 - accuracy: 0.9832 - val_loss: 0.3528 - val_accuracy: 0.8996
# Epoch 43/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0359 - accuracy: 0.9889 - val_loss: 0.3980 - val_accuracy: 0.9027
# Epoch 44/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0255 - accuracy: 0.9909 - val_loss: 0.3798 - val_accuracy: 0.9110
# Epoch 45/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0370 - accuracy: 0.9886 - val_loss: 0.5683 - val_accuracy: 0.8882
# Epoch 46/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.0250 - accuracy: 0.9935 - val_loss: 0.3883 - val_accuracy: 0.9058
# Epoch 47/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0236 - accuracy: 0.9917 - val_loss: 0.4686 - val_accuracy: 0.8965
# Epoch 48/100
# 121/121 [==============================] - 6s 50ms/step - loss: 0.0384 - accuracy: 0.9858 - val_loss: 0.4018 - val_accuracy: 0.8944
# Epoch 49/100
# 121/121 [==============================] - 6s 47ms/step - loss: 0.0268 - accuracy: 0.9909 - val_loss: 0.3161 - val_accuracy: 0.9110
# Epoch 50/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0342 - accuracy: 0.9884 - val_loss: 0.3944 - val_accuracy: 0.8954
# Epoch 51/100
# 121/121 [==============================] - 6s 50ms/step - loss: 0.0383 - accuracy: 0.9889 - val_loss: 0.4886 - val_accuracy: 0.8965
# Epoch 52/100
# 121/121 [==============================] - 5s 44ms/step - loss: 0.0283 - accuracy: 0.9904 - val_loss: 0.4102 - val_accuracy: 0.9037
# Epoch 53/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0254 - accuracy: 0.9909 - val_loss: 0.5424 - val_accuracy: 0.8975
# Epoch 54/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0280 - accuracy: 0.9907 - val_loss: 0.3406 - val_accuracy: 0.9141
# Epoch 55/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.0272 - accuracy: 0.9907 - val_loss: 0.5083 - val_accuracy: 0.8934
# Epoch 56/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0389 - accuracy: 0.9855 - val_loss: 0.4007 - val_accuracy: 0.9058
# Epoch 57/100
# 121/121 [==============================] - 7s 54ms/step - loss: 0.0212 - accuracy: 0.9925 - val_loss: 0.4341 - val_accuracy: 0.9017
# Epoch 58/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0189 - accuracy: 0.9940 - val_loss: 0.4984 - val_accuracy: 0.8882
# Epoch 59/100
# 121/121 [==============================] - 6s 48ms/step - loss: 0.0482 - accuracy: 0.9850 - val_loss: 0.3671 - val_accuracy: 0.9079
# Epoch 60/100
# 121/121 [==============================] - 6s 49ms/step - loss: 0.0344 - accuracy: 0.9889 - val_loss: 0.3505 - val_accuracy: 0.9058
# Epoch 61/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.4072 - val_accuracy: 0.9120
# Epoch 62/100
# 121/121 [==============================] - 6s 52ms/step - loss: 0.0169 - accuracy: 0.9933 - val_loss: 0.3861 - val_accuracy: 0.9130
# Epoch 63/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0193 - accuracy: 0.9946 - val_loss: 0.3960 - val_accuracy: 0.9172
# Epoch 64/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.4753 - val_accuracy: 0.9017
# Epoch 65/100
# 121/121 [==============================] - 6s 45ms/step - loss: 0.0333 - accuracy: 0.9894 - val_loss: 0.3907 - val_accuracy: 0.9068
# Epoch 66/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.5529 - val_accuracy: 0.8954
# Epoch 67/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0298 - accuracy: 0.9909 - val_loss: 0.4348 - val_accuracy: 0.8996
# Epoch 68/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.4097 - val_accuracy: 0.9058
# Epoch 69/100
# 121/121 [==============================] - 6s 46ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.3835 - val_accuracy: 0.9099
# Epoch 70/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.4595 - val_accuracy: 0.9048
# Epoch 71/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0574 - accuracy: 0.9814 - val_loss: 0.4646 - val_accuracy: 0.8934
# Epoch 72/100
# 121/121 [==============================] - 6s 46ms/step - loss: 0.0302 - accuracy: 0.9899 - val_loss: 0.4446 - val_accuracy: 0.9151
# Epoch 73/100
# 121/121 [==============================] - 6s 51ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 0.4345 - val_accuracy: 0.9151
# Epoch 74/100
# 121/121 [==============================] - 7s 59ms/step - loss: 0.0128 - accuracy: 0.9951 - val_loss: 0.4276 - val_accuracy: 0.9110
# Epoch 75/100
# 121/121 [==============================] - 6s 52ms/step - loss: 0.0274 - accuracy: 0.9894 - val_loss: 0.4278 - val_accuracy: 0.9182
# Epoch 76/100
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0149 - accuracy: 0.9935 - val_loss: 0.4848 - val_accuracy: 0.9068
# Epoch 77/100
# 121/121 [==============================] - 7s 56ms/step - loss: 0.0125 - accuracy: 0.9956 - val_loss: 0.4404 - val_accuracy: 0.9130
# Epoch 78/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.5269 - val_accuracy: 0.9027
# Epoch 79/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0207 - accuracy: 0.9909 - val_loss: 0.5389 - val_accuracy: 0.9110
# Epoch 80/100
# 121/121 [==============================] - 5s 43ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 0.4600 - val_accuracy: 0.9110
# Epoch 81/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0207 - accuracy: 0.9935 - val_loss: 0.4413 - val_accuracy: 0.9099
# Epoch 82/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.4530 - val_accuracy: 0.9058
# Epoch 83/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.4276 - val_accuracy: 0.9079
# Epoch 84/100
# 121/121 [==============================] - 6s 46ms/step - loss: 0.0169 - accuracy: 0.9930 - val_loss: 0.4123 - val_accuracy: 0.9182
# Epoch 85/100
# 121/121 [==============================] - 6s 51ms/step - loss: 0.0334 - accuracy: 0.9915 - val_loss: 0.4901 - val_accuracy: 0.8892
# Epoch 86/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.5360 - val_accuracy: 0.8986
# Epoch 87/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0192 - accuracy: 0.9938 - val_loss: 0.4108 - val_accuracy: 0.9120
# Epoch 88/100
# 121/121 [==============================] - 6s 51ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 0.5008 - val_accuracy: 0.9068
# Epoch 89/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0128 - accuracy: 0.9946 - val_loss: 0.3847 - val_accuracy: 0.9172
# Epoch 90/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0271 - accuracy: 0.9925 - val_loss: 0.6141 - val_accuracy: 0.8944
# Epoch 91/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0308 - accuracy: 0.9899 - val_loss: 0.4749 - val_accuracy: 0.9068
# Epoch 92/100
# 121/121 [==============================] - 7s 55ms/step - loss: 0.0188 - accuracy: 0.9930 - val_loss: 0.5493 - val_accuracy: 0.8954
# Epoch 93/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0352 - accuracy: 0.9917 - val_loss: 0.5270 - val_accuracy: 0.9058
# Epoch 94/100
# 121/121 [==============================] - 6s 53ms/step - loss: 0.0249 - accuracy: 0.9917 - val_loss: 0.5434 - val_accuracy: 0.8986
# Epoch 95/100
# 121/121 [==============================] - 5s 45ms/step - loss: 0.0283 - accuracy: 0.9904 - val_loss: 0.4655 - val_accuracy: 0.9089
# Epoch 96/100
# 121/121 [==============================] - 6s 47ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 0.4386 - val_accuracy: 0.9172
# Epoch 97/100
# 121/121 [==============================] - 6s 47ms/step - loss: 0.0279 - accuracy: 0.9920 - val_loss: 0.4827 - val_accuracy: 0.9193
# Epoch 98/100
# 121/121 [==============================] - 5s 44ms/step - loss: 0.0133 - accuracy: 0.9959 - val_loss: 0.4753 - val_accuracy: 0.9141
# Epoch 99/100
# 121/121 [==============================] - 6s 52ms/step - loss: 0.0287 - accuracy: 0.9935 - val_loss: 0.4398 - val_accuracy: 0.9089
# Epoch 100/100
# 121/121 [==============================] - 5s 42ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.4239 - val_accuracy: 0.9182

# %%
#Display of the accuracy and the loss values
import matplotlib.pyplot as plt

plt.figure(figsize = (8,8))
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss/accuracy')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.utils import plot_model
plot_model(model)

# %%
Y_pred_probabilities = model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred_probabilities, axis=1)
# Out:
# 33/33 [==============================] - 1s 19ms/step

# %%
#converting over Y test to actual labels.
Y_test = np.argmax(Y_test, axis = 1)

# %%
# Prediksi probabilitas kelas menggunakan model
Y_pred_probabilities = model.predict(X_test)

# Ambil indeks kelas dengan probabilitas tertinggi untuk setiap sampel
Y_pred_classes = np.argmax(Y_pred_probabilities, axis=1)

# Hitung dan cetak akurasi
from sklearn.metrics import accuracy_score
print('Akurasi yang diperoleh pada set pengujian adalah:', accuracy_score(Y_pred_classes, Y_test))
# Out:
# 33/33 [==============================] - 0s 14ms/step
# Akurasi yang diperoleh pada set pengujian adalah: 0.9188405797101449

# %%
# Prediksi probabilitas kelas menggunakan model
Y_pred_probabilities = model.predict(X_test)

# Ambil indeks kelas dengan probabilitas tertinggi untuk setiap sampel
Y_pred_classes = np.argmax(Y_pred_probabilities, axis=1)

# Cetak laporan klasifikasi
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred_classes))
# Out:
# 33/33 [==============================] - 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98       113
#            1       0.96      0.97      0.96       139
#            2       0.76      0.78      0.77       125
#            3       0.70      0.64      0.67       108
#            4       0.92      0.94      0.93       119
#            5       0.99      1.00      1.00       166
#            6       0.96      0.98      0.97       110
#            7       0.99      1.00      0.99       155
#
#     accuracy                           0.92      1035
#    macro avg       0.91      0.91      0.91      1035
# weighted avg       0.92      0.92      0.92      1035
